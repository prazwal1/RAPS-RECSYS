# %%
import pandas as pd

# %%
df=pd.read_csv('olist_products_dataset.csv')
df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
df[df.product_id=='0d009643171aee696f4733340bc2fdd0']
# Out:
#                           product_id product_category_name  \
# 77  0d009643171aee696f4733340bc2fdd0            perfumaria
#
#     product_name_lenght  product_description_lenght  product_photos_qty  \
# 77                 52.0                       150.0                 1.0
#
#     product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 77             422.0               21.0               16.0              18.0

# %%
df1=pd.read_csv('product_category_name_translation.csv')
df1.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
#merging df and df1
df = pd.merge(df,df1)
df.head()
# Out:
#                          product_id product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5            perfumaria
# 1  6a2fb4dd53d2cdb88e0432f1284a004c            perfumaria
# 2  0d009643171aee696f4733340bc2fdd0            perfumaria
# 3  b1eae565a61935e0011ee7682fef9dc9            perfumaria
# 4  8da90b37f0fb171b4877c124f965b1f6            perfumaria
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 39.0                       346.0                 2.0
# 2                 52.0                       150.0                 1.0
# 3                 49.0                       460.0                 2.0
# 4                 56.0                       733.0                 3.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             225.0               16.0               10.0              14.0
# ...

# %%
df=df[['product_id','product_category_name','product_category_name_english','product_name_lenght','product_description_lenght','product_photos_qty','product_weight_g','product_length_cm','product_height_cm','product_width_cm']]
df.head()
# Out:
#                          product_id product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5            perfumaria
# 1  6a2fb4dd53d2cdb88e0432f1284a004c            perfumaria
# 2  0d009643171aee696f4733340bc2fdd0            perfumaria
# 3  b1eae565a61935e0011ee7682fef9dc9            perfumaria
# 4  8da90b37f0fb171b4877c124f965b1f6            perfumaria
#
#   product_category_name_english  product_name_lenght  \
# 0                     perfumery                 40.0
# 1                     perfumery                 39.0
# 2                     perfumery                 52.0
# 3                     perfumery                 49.0
# 4                     perfumery                 56.0
#
#    product_description_lenght  product_photos_qty  product_weight_g  \
# 0                       287.0                 1.0             225.0
# 1                       346.0                 2.0             400.0
# 2                       150.0                 1.0             422.0
# ...

# %%
g=df.groupby('product_category_name_english')

# %%
g.size()
# Out:
# product_category_name_english
# agro_industry_and_commerce                   74
# air_conditioning                            124
# art                                          55
# arts_and_craftmanship                        19
# audio                                        58
# auto                                       1900
# baby                                        919
# bed_bath_table                             3029
# books_general_interest                      216
# books_imported                               31
# books_technical                             123
# cds_dvds_musicals                             1
# christmas_supplies                           65
# cine_photo                                   28
# computers                                    30
# computers_accessories                      1639
# consoles_games                              317
# construction_tools_construction             400
# construction_tools_lights                    78
# ...

# %%
df.to_csv ("new_products.csv",index=False)
df['product_id'][1]
# Out:
# '6a2fb4dd53d2cdb88e0432f1284a004c'

# %%
#a=cat_name +' '+ "Product"+' '+str(product_id[i])
i=1 #after assingnig global keyword now you can modify the value otherwise you can only use it
def gen_product_names(cat_name,product_id):
    global i 
    a=cat_name +' '+ "Product"+' '+str(i)
    i=i+1
    return a


df['product_name']=df.product_category_name_english.apply(gen_product_names,product_id=df.product_id)
df.head(1000)
# Out:
#                            product_id product_category_name  \
# 0    1e9e8ef04dbcff4541ed26657ea517e5            perfumaria
# 1    6a2fb4dd53d2cdb88e0432f1284a004c            perfumaria
# 2    0d009643171aee696f4733340bc2fdd0            perfumaria
# 3    b1eae565a61935e0011ee7682fef9dc9            perfumaria
# 4    8da90b37f0fb171b4877c124f965b1f6            perfumaria
# ..                                ...                   ...
# 995  cb57afec681197430ddab41d90304aba         esporte_lazer
# 996  003128f981470c3e5a2e7445e4a771cd         esporte_lazer
# 997  8058b0067728a211c68874081e7352d4         esporte_lazer
# 998  45af837344fa95e1fb3a840e9ffd8bf4         esporte_lazer
# 999  1ed390fc2e1df06251341c288d315eea         esporte_lazer
#
#     product_category_name_english  product_name_lenght  \
# 0                       perfumery                 40.0
# 1                       perfumery                 39.0
# 2                       perfumery                 52.0
# ...
