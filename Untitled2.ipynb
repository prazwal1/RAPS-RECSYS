# %%
import pandas as pd

# %%
df = pd.read_csv('olist_order_items_dataset.csv')
df[df.product_id == "4244733e06e7ecb4970a6e2683c13e61"]
# Out:
#                                order_id  order_item_id  \
# 0      00010242fe8c5a6d1ba2dd792cb16214              1
# 8346   130898c0987d1801452a8ed92a670612              1
# 36646  532ed5e14e24ae1f0d735b91524b98b9              1
# 49108  6f8c31653edb8c83e1a739408b5ff750              1
# 55021  7d19f4ef4d04461989632411b7e588b9              1
# 70534  a0f9acf0b6294ed8561e32cde1a966bc              1
# 82756  bbf796534aaf9c59f8da8c7982db56e0              1
# 88891  c9ef97d2854afe64a3b4488bc2836af6              2
# 98401  df2d910b8b5e5f461f67043489f9569d              1
#
#                              product_id                         seller_id  \
# 0      4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 8346   4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 36646  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 49108  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# ...

# %%
x = df.groupby('product_id')['order_item_id'].sum()
data = pd.DataFrame(x)
data.drop_duplicates(inplace = True)
data.sort_values(by = 'order_item_id',ascending = False)
# Out:
#                                   order_item_id
# product_id
# 422879e10f46682990de24d770e7f83d            793
# aca2eb7d00ea1a7b8ebd4e68314663af            640
# 368c6c730842d78016ad823897a372db            551
# 53759a2ecddad2bb87a079a1f1519f73            545
# 99a4788cb24856965c36a24e339b6058            542
# ...                                         ...
# 004636c889c7c3dad6631f136b7fa082              5
# 00ae7076313576f94d9107599d79a978              4
# 003c0b8f6580c850bd2e32044d2ac307              3
# 000b8f95fcb9e0096488278317764d19              2
# 00066f42aeeb9f3007548bb9d3f33c38              1
#
# [157 rows x 1 columns]

# %%
DF = pd.read_csv('final_features.csv')
DF
# Out:
#        Unnamed: 0                        product_id  seller_index  \
# 0               0  00066f42aeeb9f3007548bb9d3f33c38             2
# 1               1  00088930e925c41fd95ebfe695fd2655             2
# 2               2  0009406fd7479715e4bef61dd91f2462             2
# 3               3  000b8f95fcb9e0096488278317764d19             2
# 4               4  000d9be29b5207b54e86aa1b1ac54872             2
# ...           ...                               ...           ...
# 32946       32946  fff6177642830a9a94a0f2cba5e476d1             2
# 32947       32947  fff81cc3158d2725c0655ab9ba0f712c             2
# 32948       32948  fff9553ac224cec9d15d49f5a263411f             2
# 32949       32949  fffdb2d0ec8d6a61f0a0a0db3f25b441             2
# 32950       32950  fffe9eeff12fcbd74a2f2b007dde0c58            12
#
#        category_index  review_score  order_item_id
# 0                 2.9           5.0            1.0
# 1                14.5           4.0            0.0
# ...

# %%
y = pd.merge(DF,data,on='product_id',how='outer')

# %%
y.fillna(0, inplace = True)
y.reset_index(inplace = True ,drop = True)
y.to_csv('final_features.csv',index = False)

# %%
# Out:
#        Unnamed: 0                        product_id  seller_index  \
# 0               0  00066f42aeeb9f3007548bb9d3f33c38             2
# 1               1  00088930e925c41fd95ebfe695fd2655             2
# 2               2  0009406fd7479715e4bef61dd91f2462             2
# 3               3  000b8f95fcb9e0096488278317764d19             2
# 4               4  000d9be29b5207b54e86aa1b1ac54872             2
# ...           ...                               ...           ...
# 32946       32946  fff6177642830a9a94a0f2cba5e476d1             2
# 32947       32947  fff81cc3158d2725c0655ab9ba0f712c             2
# 32948       32948  fff9553ac224cec9d15d49f5a263411f             2
# 32949       32949  fffdb2d0ec8d6a61f0a0a0db3f25b441             2
# 32950       32950  fffe9eeff12fcbd74a2f2b007dde0c58            12
#
#        category_index  review_score  order_item_id
# 0                 2.9           5.0            1.0
# 1                14.5           4.0            0.0
# ...
