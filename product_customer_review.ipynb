# %%
import pandas as pd
import surprise
import numpy as np

# %%
dataset1 = pd.read_csv('new_products.csv')
dataset1.head(100)
# Out:
#                           product_id product_category_name  \
# 0   1e9e8ef04dbcff4541ed26657ea517e5            perfumaria
# 1   6a2fb4dd53d2cdb88e0432f1284a004c            perfumaria
# 2   0d009643171aee696f4733340bc2fdd0            perfumaria
# 3   b1eae565a61935e0011ee7682fef9dc9            perfumaria
# 4   8da90b37f0fb171b4877c124f965b1f6            perfumaria
# ..                               ...                   ...
# 95  f2b67cf6ef88cbc9c2f3e482f558b318            perfumaria
# 96  fa157aa51a996cc533b9048c3c8118a0            perfumaria
# 97  aa8bc5595ba5d066c744e14995402cdd            perfumaria
# 98  29b65c78c1d8d70da25c6a553e1bfdb1            perfumaria
# 99  c344623528c017d4fa7c51cb56d17a98            perfumaria
#
#    product_category_name_english  product_name_lenght  \
# 0                      perfumery                 40.0
# 1                      perfumery                 39.0
# 2                      perfumery                 52.0
# ...

# %%
dataset2 = pd.read_csv('olist_order_items_dataset.csv')
dataset2.head(100)
# Out:
#                             order_id  order_item_id  \
# 0   00010242fe8c5a6d1ba2dd792cb16214              1
# 1   00018f77f2f0320c557190d7a144bdd3              1
# 2   000229ec398224ef6ca0657da4fc703e              1
# 3   00024acbcdf0a6daa1e931b038114c75              1
# 4   00042b26cf59d7ce69dfabb4e55b4fd9              1
# ..                               ...            ...
# 95  0035246a40f520710769010f752e7507              1
# 96  0035c0b07126fe9c24a325216fb96064              1
# 97  0035e6b7ade84b3f5b86bd49814793df              1
# 98  0036757472ece3dde52fd4bfd929c90e              1
# 99  0036887767dea4bd43b1a88cd0d9477a              1
#
#                           product_id                         seller_id  \
# 0   4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1   e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2   c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# ...

# %%
dataset3 = pd.read_csv('olist_order_reviews_dataset.csv')
dataset3.head(100)
# Out:
#                            review_id                          order_id  \
# 0   7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1   80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2   228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3   e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4   f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ..                               ...                               ...
# 95  71bc170a5ad41ee9dee95f82a17860a8  a90b081d0efa436e072d5328ecd904a4
# 96  c5be8de5421e658a45042d6ca6a4ff64  61665389f0cccf5ec8135e3b05efc714
# 97  0c8b57ea62de568f13a0e101d344977e  41bc5a3d34a8e4ef91b2e7d9500694cf
# 98  edfbad2944ea758725486c3bbcd04f49  9d2aa61b374fac5dd063f36fefa602e1
# 99  bbf6c18e7c5a88b6adcb69af3b971207  828a705e0645673b538e803ca75a29b6
#
#     review_score review_comment_title  \
# 0              4                  NaN
# ...

# %%
dataset5 = pd.read_csv('olist_customers_dataset.csv')
dataset5.head(100)
# Out:
#                          customer_id                customer_unique_id  \
# 0   06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1   18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2   4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3   b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4   4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ..                               ...                               ...
# 95  f89c1a6b9c966869e441e55bc14acddc  809353196a0456095716566dd226bb48
# 96  23e96758fd640560e9b1fbcda90abfc4  9e1f719fe5b17b9c51905fee6d6385c1
# 97  369708cabd9831ea6fde670a3b602a92  94b731a41867b47c3856e324840c4c99
# 98  5f8b4882b5a4ec7bf6d2107e6cd0cf29  694cb45ff29b603ac2acd51016770097
# 99  ad6891a1937cb8723a2c08ba1ae59873  9dbb05f5577e862337b93feb8f358839
#
#     customer_zip_code_prefix          customer_city customer_state
# ...

# %%
dataset6 = pd.read_csv('olist_sellers_dataset.csv')
dataset6.head(100)
# Out:
#                            seller_id  seller_zip_code_prefix  \
# 0   3442f8959a84dea7ee197c632cb2df15                   13023
# 1   d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2   ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3   c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4   51a04a8a6bdcb23deccc82b0b80742cf                   12914
# ..                               ...                     ...
# 95  cda598c48d7c614bc1cad7d8ff6f0010                   15137
# 96  d4910f1cdcfdabd48d6b316e395d4a23                    9190
# 97  709e16e2b25c7474d980076c6bfc4806                   16200
# 98  9dc79dd988ac42f4d56c340d7048420a                    3569
# 99  276677b5d08786d5dce7c2149dcce48b                   31730
#
#           seller_city seller_state
# 0            campinas           SP
# 1          mogi guacu           SP
# 2      rio de janeiro           RJ
# 3           sao paulo           SP
# 4   braganca paulista           SP
# ...

# %%
dataset7 = pd.read_csv('olist_orders_dataset.csv')
dataset7.head(100)
# Out:
#                             order_id                       customer_id  \
# 0   e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1   53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2   47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3   949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4   ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ..                               ...                               ...
# 95  77e9941864fc840be8e4b1ba5347c0f7  3135962ee745ef39b85576df7ddbaa99
# 96  41bb5cee06dbf170878a9ef93ac7e7f5  1833a0540067becaf59368fe4cd4303a
# 97  6a0a8bfbbe700284feb0845d95e0867f  68451b39b1314302c08c65a29f1140fc
# 98  f7959f8385f34c4f645327465a1c9fc4  0bf19317b1830a69e55b40710576aa7a
# 99  23f553848a03aaab35bb3f9f87725125  c622b892a190735ef81c0087973fa16d
#
#    order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
dataset4 = pd.merge(dataset2,dataset3)
dataset4.head(100)
# Out:
#                             order_id  order_item_id  \
# 0   00010242fe8c5a6d1ba2dd792cb16214              1
# 1   00018f77f2f0320c557190d7a144bdd3              1
# 2   000229ec398224ef6ca0657da4fc703e              1
# 3   00024acbcdf0a6daa1e931b038114c75              1
# 4   00042b26cf59d7ce69dfabb4e55b4fd9              1
# ..                               ...            ...
# 95  0035246a40f520710769010f752e7507              1
# 96  0035246a40f520710769010f752e7507              1
# 97  0035c0b07126fe9c24a325216fb96064              1
# 98  0035e6b7ade84b3f5b86bd49814793df              1
# 99  0036757472ece3dde52fd4bfd929c90e              1
#
#                           product_id                         seller_id  \
# 0   4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1   e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2   c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# ...

# %%
dataset = pd.merge(dataset4,dataset7)
dataset.head(100)
# Out:
#                             order_id  order_item_id  \
# 0   00010242fe8c5a6d1ba2dd792cb16214              1
# 1   00018f77f2f0320c557190d7a144bdd3              1
# 2   000229ec398224ef6ca0657da4fc703e              1
# 3   00024acbcdf0a6daa1e931b038114c75              1
# 4   00042b26cf59d7ce69dfabb4e55b4fd9              1
# ..                               ...            ...
# 95  0035246a40f520710769010f752e7507              1
# 96  0035246a40f520710769010f752e7507              1
# 97  0035c0b07126fe9c24a325216fb96064              1
# 98  0035e6b7ade84b3f5b86bd49814793df              1
# 99  0036757472ece3dde52fd4bfd929c90e              1
#
#                           product_id                         seller_id  \
# 0   4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1   e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2   c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# ...

# %%
dataset = dataset[['customer_id','product_id','review_score']]
dataset.head()
# Out:
#                         customer_id                        product_id  \
# 0  3ce436f183e68e07877b285a838db11a  4244733e06e7ecb4970a6e2683c13e61
# 1  f6dd3ec061db4e3987629fe6b26e5cce  e5f2d52b802189ee658865ca93d83a8f
# 2  6489ae5e4333f3693df5ad4372dab6d3  c777355d18b72b67abbeef9df44fd0fd
# 3  d4eb9395c8c0431ee92fce09860c5a06  7634da152a4610f1595efa32f14722fc
# 4  58dbd0b2d70206bf40e62cd34e84d795  ac6c3623068f30de03045865e4e10089
#
#    review_score
# 0             5
# 1             4
# 2             5
# 3             4
# 4             5

# %%
dataset.to_csv ("user_product_review.csv",index=False)
